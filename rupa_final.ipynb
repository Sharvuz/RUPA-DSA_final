# %% [markdown]
# # RUPA-DSA_Final

# %% [markdown]
# ## cài pytorch

# %%
import sys
import subprocess

subprocess.run([
    sys.executable, "-m", "pip", "install",
    "--no-cache-dir",
    "--force-reinstall",
    "torch==2.6.0",
    "torchvision==0.21.0",
    "torchaudio==2.6.0",
    "--index-url", "https://download.pytorch.org/whl/cu124"
], check=True)

print("Đã cài PyTorch tương thích P100. Hãy Restart Session.")

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0))
print("Architectures:", torch.cuda.get_arch_list())

assert torch.cuda.is_available()
assert "sm_60" in torch.cuda.get_arch_list()

x = torch.randn(1024, 1024, device="cuda")
y = x @ x
print("P100 CUDA test thành công:", y.device)

# %% [markdown]
# # UCF

# %%
# ========================= USER CONFIG =========================
DATASET = "ucf"             
MAX_EPOCHS = 5             
UCF_BATCH_SIZE = 48      # Nếu bị tràn RAM, bạn hãy hạ xuống 32 nhé
NUM_WORKERS = 2
SEED = 234
RESUME = False
# Khai báo đường dẫn tới GitHub (Sửa lỗi NameError)
REPO_URL = "https://github.com/Sharvuz/RUPA-DSA_final.git"
REPO_REF = None
# [QUAN TRỌNG] ĐƯỜNG DẪN ĐẾN FILE CHECKPOINT DSANET GỐC DÙNG LÀM ĐÀ PHÓNG
INIT_MODEL_PATH = "/kaggle/input/models/vhunhquang/dsanet-checkpoint/pytorch/default/1/dsanet_model_ucf.pth"

# %%
import json, os, random, shutil, subprocess, sys, time, zipfile
from pathlib import Path

WORK = Path("/kaggle/working")
INPUT = Path("/kaggle/input")
REPO = WORK / "RUPA-DSA"
ARTIFACTS = WORK / "rupa_artifacts"
ARTIFACTS.mkdir(parents=True, exist_ok=True)

if REPO.exists():
    shutil.rmtree(REPO)
clone_cmd = ["git", "clone", "--depth", "1"]
if REPO_REF:
    clone_cmd += ["--branch", REPO_REF]
clone_cmd += [REPO_URL, str(REPO)]
subprocess.run(clone_cmd, check=True)
os.chdir(REPO)

subprocess.run([
    sys.executable, "-m", "pip", "install", "-q",
    "ftfy", "regex", "einops==0.8.0", "ipdb", "scikit-learn", "pandas"
], check=True)

import numpy as np
import pandas as pd
import torch

print("Repository:", REPO_URL, "ref:", REPO_REF or "default branch")
print("PyTorch:", torch.__version__)
print("CUDA runtime:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NONE")
assert torch.cuda.is_available(), "Enable Accelerator = GPU in Kaggle Notebook Settings."
assert "RUPA-DSA" in (REPO / "src/model.py").read_text(encoding="utf-8")

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
print("Direct GitHub clone ready.")

# %%
from collections import defaultdict
from pathlib import PurePosixPath

if DATASET == "ucf":
    csv_specs = [
        ("list/ucf_CLIP_rgb.csv", "ucf_train.csv"),
        ("list/ucf_CLIP_rgbtest.csv", "ucf_test.csv"),
    ]
    zip_hints = ["ucfclipfeatures"]
else:
    csv_specs = [
        ("list/xd_CLIP_rgb.csv", "xd_train.csv"),
        ("list/xd_CLIP_rgbtest.csv", "xd_test.csv"),
    ]
    zip_hints = ["xdtrainclipfeatures", "xdtestclipfeatures"]

def basename(path_string):
    return PurePosixPath(str(path_string).replace("\\", "/")).name

required_names = set()
for csv_rel, _ in csv_specs:
    frame = pd.read_csv(REPO / csv_rel)
    required_names.update(basename(p) for p in frame["path"])

feature_roots = [INPUT]

def indexed_names(roots):
    return {p.name for root in roots for p in root.rglob("*.npy")}

missing_before = required_names - indexed_names(feature_roots)
if missing_before:
    extract_root = WORK / f"rupa_features_{DATASET}"
    extract_root.mkdir(parents=True, exist_ok=True)
    archives = [
        p for p in INPUT.rglob("*.zip")
        if any(hint in p.stem.lower() for hint in zip_hints)
    ]
    if archives:
        print(f"Extracting {len(archives)} feature archive(s); this can take several minutes...")
    for archive_path in archives:
        destination = (extract_root / archive_path.stem).resolve()
        destination.mkdir(parents=True, exist_ok=True)
        with zipfile.ZipFile(archive_path) as archive:
            for member in archive.infolist():
                target = (destination / member.filename).resolve()
                if destination not in target.parents and target != destination:
                    raise RuntimeError(f"Unsafe ZIP member: {member.filename}")
            archive.extractall(destination)
        print("Extracted:", archive_path.name)
    feature_roots.append(extract_root)

index = defaultdict(list)
for root in feature_roots:
    for path in root.rglob("*.npy"):
        if path.name in required_names:
            index[path.name].append(path)

def rank_candidate(candidate, original):
    original_parts = [x.lower() for x in str(original).replace("\\", "/").split("/")[-4:]]
    candidate_text = str(candidate).lower()
    return sum(part in candidate_text for part in original_parts)

def rewrite_csv(csv_rel, output_name):
    frame = pd.read_csv(REPO / csv_rel)
    resolved, missing, ambiguous = [], [], 0
    for original in frame["path"].astype(str):
        matches = index.get(basename(original), [])
        if not matches:
            missing.append(basename(original))
            resolved.append("")
            continue
        matches = sorted(matches, key=lambda p: rank_candidate(p, original), reverse=True)
        resolved.append(str(matches[0]))
        ambiguous += int(len(matches) > 1)
    if missing:
        raise FileNotFoundError(
            f"{csv_rel}: missing {len(missing)}/{len(frame)} features; examples={missing[:10]}"
        )
    output = ARTIFACTS / output_name
    frame["path"] = resolved
    frame.to_csv(output, index=False)
    print(f"{output_name}: rows={len(frame)}, missing=0, duplicate basenames={ambiguous}")
    return output

train_csv = rewrite_csv(*csv_specs[0])
test_csv = rewrite_csv(*csv_specs[1])

sample_path = Path(pd.read_csv(train_csv).iloc[0]["path"])
sample = np.load(sample_path, mmap_mode="r")
assert sample.ndim == 2 and sample.shape[-1] == 512, (
    f"Expected CLIP feature [T,512], got {sample.shape} from {sample_path}"
)
print("Feature preflight:", sample_path.name, sample.shape)

# %%
# ========================= TEST MODEL =========================
import subprocess, sys, os
from pathlib import Path

# Đã sửa lại đúng đường dẫn Kaggle Dataset mới của bạn
TEST_MODEL_PATH = "/kaggle/input/models/vhunhquang/dsanet-checkpoint/pytorch/default/1/dsanet_model_ucf.pth"

# Khai báo lại đường dẫn phòng hờ
DATASET = "ucf"
REPO_DIR = "/kaggle/working/RUPA-DSA"
ARTIFACTS = Path("/kaggle/working/rupa_artifacts")
test_csv = ARTIFACTS / f"{DATASET}_test.csv"

# 1. Tự động Clone code nếu chưa có
if not os.path.exists(REPO_DIR):
    print("📥 Đang tải mã nguồn từ GitHub về Kaggle...", flush=True)
    subprocess.run(["git", "clone", "https://github.com/Sharvuz/RUPA-DSA_final.git", REPO_DIR])

cmd_test = [
    sys.executable, "-u", "src/ucf_test.py",
    "--test-list", str(test_csv),
    "--model-path", str(TEST_MODEL_PATH),
    
    # RẤT QUAN TRỌNG: 
    # Vì file này là DSANet gốc, KHÔNG có cấu trúc RUPA bên trong
    # Nên bắt buộc phải tắt RUPA để chấm điểm chính xác sức mạnh gốc của nó!
    "--rupa-use", "false", 
    "--DNP_use", "true"
]

print(f"\n🔍 Bắt đầu kiểm tra model dsanet: {TEST_MODEL_PATH} ...\n", flush=True)

process_test = subprocess.Popen(
    cmd_test, cwd=REPO_DIR, text=True,
    stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=1,
)

for line in process_test.stdout:
    print(line, end="")
    sys.stdout.flush()

process_test.wait()

# %% [markdown]
#  #### AUC1: 0.8953996818892952 AP1: 0.37849203810250753
# #### AUC2: 0.8953996999604814 AP2: 0.378486630436927
# #### mAP@0.1 =20.54%
# #### mAP@0.2 =13.12%
# #### mAP@0.3 =9.88%
# #### mAP@0.4 =8.57%
# #### mAP@0.5 =6.72%
# #### average MAP: 11.76

# %%
# ========================= TRAINING =========================
import json, os, subprocess, sys, time
from pathlib import Path
# Định nghĩa đường dẫn
ARTIFACTS = Path("/kaggle/working/rupa_artifacts")
REPO = Path("/kaggle/working/RUPA-DSA")
dataset_dir = ARTIFACTS / DATASET
dataset_dir.mkdir(parents=True, exist_ok=True)
checkpoint_path = dataset_dir / f"checkpoint_{DATASET}.pth"
model_path = dataset_dir / f"best_{DATASET}.pth"
train_csv = ARTIFACTS / f"{DATASET}_train.csv"
test_csv = ARTIFACTS / f"{DATASET}_test.csv"
cmd = [
    sys.executable, "-u", f"src/{DATASET}_train.py",
    "--train-list", str(train_csv),
    "--test-list", str(test_csv),
    "--model-path", str(model_path),
    "--checkpoint-path", str(checkpoint_path),
    
    "--max-epoch", str(MAX_EPOCHS),
    "--batch-size", str(UCF_BATCH_SIZE),
    "--num-workers", str(NUM_WORKERS),
    "--seed", str(SEED),
    # ------------------ BẬT RUPA FINAL ------------------
    "--rupa-use", "true",
    
    "--adaptive_normal_selection", "false",  # tắt bật Otsu
    
    # 2. Bật Warm Start (Kế thừa tri thức từ file DSANet gốc)
    "--init-model-path", str(INIT_MODEL_PATH),
    
    # 3. Bật Safe Gate cho Routing
    "--routing-mode", "safe_gate",
    "--main-lr", "0.0",         # Đóng băng nhánh DSANet
    "--refiner-lr", "1e-5",     # Chỉ cho phép nhánh RUPA học tiếp
    # Các trọng số RUPA
    "--routing-det-weight", "0.5",  
    "--routing-rec-weight", "0.3",   
    "--routing-sem-weight", "0.2",   
    "--loss-residual-weight", "1.0",
    "--loss-reconstructed-normal-weight", "1.0",
    "--loss-dnp-normal-weight", "0.1",
    "--loss-consistency-weight", "1.0",
    "--loss-gather-weight", "1.0",
]
if RESUME:
    cmd.extend(["--use-checkpoint", "true"])
log_path = dataset_dir / f"train_{DATASET}_FINAL.log"
started = time.time()
env = os.environ.copy()
env["PYTHONUNBUFFERED"] = "1"
print(f"🚀 Bắt đầu train bản FINAL (no Otsu + WarmStart) với {MAX_EPOCHS} Epochs...\n", flush=True)
with log_path.open("w", encoding="utf-8") as log_file:
    process = subprocess.Popen(
        cmd, cwd=REPO, env=env, text=True,
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=1,
    )
    for line in process.stdout:
        print(line, end="")
        sys.stdout.flush()
        log_file.write(line)
        log_file.flush()
        
    return_code = process.wait()
if return_code != 0:
    raise RuntimeError(f"❌ Training thất bại với exit code {return_code}")
print(f"\n✅ Hoàn thành xuất sắc trong {(time.time() - started)/3600:.2f} giờ!")

# %% [markdown]
# # XD

# %%
# ========================= USER CONFIG CHO XD-VIOLENCE =========================
DATASET = "xd"             
MAX_EPOCHS = 10            # XD-Violence phức tạp hơn nên để 10 Epochs
XD_BATCH_SIZE = 64         # Máy bạn gánh được 64 thì cứ mạnh dạn dùng 64
NUM_WORKERS = 2
SEED = 234
RESUME = False

REPO_URL = "https://github.com/Sharvuz/RUPA-DSA_final.git"
REPO_REF = None

# [RẤT QUAN TRỌNG] ĐƯỜNG DẪN TỚI FILE DSANET GỐC CỦA TẬP XD-VIOLENCE
INIT_MODEL_PATH = "/kaggle/input/models/vhunhquang/dsanet-checkpoint/pytorch/default/1/dsanet_model_xd.pth"

# %%
import json, os, random, shutil, subprocess, sys, time, zipfile
from pathlib import Path

WORK = Path("/kaggle/working")
INPUT = Path("/kaggle/input")
REPO = WORK / "RUPA-DSA"
ARTIFACTS = WORK / "rupa_artifacts"
ARTIFACTS.mkdir(parents=True, exist_ok=True)

if REPO.exists():
    shutil.rmtree(REPO)
clone_cmd = ["git", "clone", "--depth", "1"]
if REPO_REF:
    clone_cmd += ["--branch", REPO_REF]
clone_cmd += [REPO_URL, str(REPO)]
subprocess.run(clone_cmd, check=True)
os.chdir(REPO)

subprocess.run([
    sys.executable, "-m", "pip", "install", "-q",
    "ftfy", "regex", "einops==0.8.0", "ipdb", "scikit-learn", "pandas"
], check=True)

import numpy as np
import pandas as pd
import torch

print("Repository:", REPO_URL, "ref:", REPO_REF or "default branch")
print("PyTorch:", torch.__version__)
print("CUDA runtime:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NONE")
assert torch.cuda.is_available(), "Enable Accelerator = GPU in Kaggle Notebook Settings."
assert "RUPA-DSA" in (REPO / "src/model.py").read_text(encoding="utf-8")

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
print("Direct GitHub clone ready.")
# Out:
# Cloning into '/kaggle/working/RUPA-DSA'...
# Repository: https://github.com/Sharvuz/RUPA-DSA_final.git ref: default branch
# PyTorch: 2.6.0+cu124
# CUDA runtime: 12.4
# GPU: Tesla P100-PCIE-16GB
# Direct GitHub clone ready.

# %%
import os
import shutil
from pathlib import Path

print("Đang quét toàn bộ hệ thống Kaggle để tìm file .npy...")

# Quét sạch sẽ toàn bộ /kaggle/input và /kaggle/working
all_npy_paths = list(Path("/kaggle/input").rglob("*.npy")) + list(Path("/kaggle/working").rglob("*.npy"))

if not all_npy_paths:
    print("CẢNH BÁO ĐỎ: KHÔNG TÌM THẤY FILE .NPY NÀO! Bạn đã Add Data XD-Violence vào Kaggle chưa?")
else:
    print(f"Radar đã quét thấy {len(all_npy_paths)} file .npy trên hệ thống!")

# Tạo từ điển bản đồ: Tên file -> Đường dẫn tuyệt đối
file_map = {path.name: path for path in all_npy_paths}

def rewrite_csv(csv_rel, output_name):
    input_csv = REPO / csv_rel
    output = ARTIFACTS / output_name
    print(f"Đang đồng bộ danh sách {input_csv.name}...")
    
    missing = []
    is_first_line = True
    
    with input_csv.open("r", encoding="utf-8") as f, output.open("w", encoding="utf-8") as out:
        for line in f:
            line = line.strip()
            if not line: continue
            
            parts = line.split(",")
            feature_path = parts[0]
            
            if is_first_line and ("path" in feature_path.lower() or "name" in feature_path.lower()):
                out.write(line + "\n")
                is_first_line = False
                continue
            is_first_line = False
            
            feature_basename = Path(feature_path).name
            
            # Thử mọi cách "biến dạng" do Kaggle tự ý đổi tên file
            possible_names = [
                feature_basename,                                # Tên gốc chuẩn
                feature_basename.replace("#", "+"),              # Kaggle đổi # thành +
                feature_basename.replace("#", ""),               # Kaggle ăn mất dấu #
                feature_basename.replace("#", "_"),              # Kaggle đổi # thành _
            ]
            
            match_found = False
            for p_name in possible_names:
                if p_name in file_map:
                    parts[0] = str(file_map[p_name])
                    out.write(",".join(parts) + "\n")
                    match_found = True
                    break
                    
            if not match_found:
                missing.append(feature_basename)
                
    if missing:
        raise FileNotFoundError(f"Lỗi: Vẫn thiếu {len(missing)} file. Ví dụ: {missing[:3]}")
        
    return output

# Tiến hành khớp nối
train_csv = rewrite_csv(f"list/{DATASET}_CLIP_rgb.csv", f"{DATASET}_train.csv")
test_csv = rewrite_csv(f"list/{DATASET}_CLIP_rgbtest.csv", f"{DATASET}_test.csv")

print("✅ Đã lập bản đồ và đồng bộ dữ liệu XD-Violence thành công 100%!")
# Out:
# Đang quét toàn bộ hệ thống Kaggle để tìm file .npy...
# Radar đã quét thấy 67046 file .npy trên hệ thống!
# Đang đồng bộ danh sách xd_CLIP_rgb.csv...
# Đang đồng bộ danh sách xd_CLIP_rgbtest.csv...
# ✅ Đã lập bản đồ và đồng bộ dữ liệu XD-Violence thành công 100%!

# %%
# ========================= TEST MODEL XD-VIOLENCE =========================
import subprocess, sys, os
from pathlib import Path

# [QUAN TRỌNG] Đảm bảo bạn điền đúng đường dẫn file DSANet gốc của tập XD
TEST_MODEL_PATH = "/kaggle/input/models/vhunhquang/dsanet-checkpoint/pytorch/default/1/dsanet_model_xd.pth"

# Khai báo đường dẫn
DATASET = "xd"
REPO_DIR = "/kaggle/working/RUPA-DSA"
ARTIFACTS = Path("/kaggle/working/rupa_artifacts")
test_csv = ARTIFACTS / f"{DATASET}_test.csv"

# Tự động Clone code nếu Kaggle vừa bị Restart
if not os.path.exists(REPO_DIR):
    print("📥 Đang tải mã nguồn từ GitHub về Kaggle...", flush=True)
    subprocess.run(["git", "clone", "https://github.com/Sharvuz/RUPA-DSA_final.git", REPO_DIR])

cmd_test = [
    sys.executable, "-u", "src/xd_test.py",
    "--test-list", str(test_csv),
    "--model-path", str(TEST_MODEL_PATH),
    
    # RẤT QUAN TRỌNG: 
    # - Nếu test file DSANet gốc (như hiện tại) -> Để "false"
    # - Nếu test file best_xd.pth của bạn (sau khi train xong) -> Nhớ sửa thành "true"
    "--rupa-use", "false", 
    "--DNP_use", "true"
]

print(f"\n🔍 Bắt đầu kiểm tra sức mạnh của model: {TEST_MODEL_PATH} ...\n", flush=True)

process_test = subprocess.Popen(
    cmd_test, cwd=REPO_DIR, text=True,
    stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=1,
)

for line in process_test.stdout:
    print(line, end="")
    sys.stdout.flush()

process_test.wait()
# Out:
# 🔍 Bắt đầu kiểm tra sức mạnh của model: /kaggle/input/models/vhunhquang/dsanet-checkpoint/pytorch/default/1/dsanet_model_xd.pth ...
#
# AUC1:  0.9539451211469483  AP1:  0.8699109897543252
# AUC2:  0.953945121014257  AP2: 0.8699109892289387
# mAP@0.1 =39.66%
# mAP@0.2 =32.20%
# mAP@0.3 =26.62%
# mAP@0.4 =20.93%
# mAP@0.5 =16.56%
# average MAP: 27.19
# 0

# %%
# ========================= TRAINING =========================
import json, os, subprocess, sys, time
from pathlib import Path
# Định nghĩa đường dẫn
ARTIFACTS = Path("/kaggle/working/rupa_artifacts")
REPO = Path("/kaggle/working/RUPA-DSA")
dataset_dir = ARTIFACTS / DATASET
dataset_dir.mkdir(parents=True, exist_ok=True)
checkpoint_path = dataset_dir / f"checkpoint_{DATASET}.pth"
model_path = dataset_dir / f"best_{DATASET}.pth"
train_csv = ARTIFACTS / f"{DATASET}_train.csv"
test_csv = ARTIFACTS / f"{DATASET}_test.csv"
cmd = [
    sys.executable, "-u", f"src/{DATASET}_train.py",
    "--train-list", str(train_csv),
    "--test-list", str(test_csv),
    "--model-path", str(model_path),
    "--checkpoint-path", str(checkpoint_path),
    
    "--max-epoch", str(MAX_EPOCHS),
    "--batch-size", str(XD_BATCH_SIZE),
    "--num-workers", str(NUM_WORKERS),
    "--seed", str(SEED),
    # ------------------ BẬT RUPA FINAL ------------------
    "--rupa-use", "true",
    
    # 1. tắt Otsu Thresholding
    "--adaptive_normal_selection", "false",
    
    # 2. Bật Warm Start (Kế thừa tri thức từ file DSANet gốc của tập XD)
    "--init-model-path", str(INIT_MODEL_PATH),
    
    # 3. Bật Safe Gate cho Routing
    "--routing-mode", "safe_gate",
    "--main-lr", "0.0",         # Đóng băng nhánh chính
    "--refiner-lr", "1e-5",     # Chỉ cho phép nhánh RUPA học tiếp
    # Các trọng số RUPA
    "--routing-det-weight", "0.5",  
    "--routing-rec-weight", "0.3",   
    "--routing-sem-weight", "0.2",   
    "--loss-residual-weight", "1.0",
    "--loss-reconstructed-normal-weight", "1.0",
    "--loss-dnp-normal-weight", "0.1",
    "--loss-consistency-weight", "1.0",
    "--loss-gather-weight", "1.0",
]
if RESUME:
    cmd.extend(["--use-checkpoint", "true"])
log_path = dataset_dir / f"train_{DATASET}_FINAL.log"
started = time.time()
env = os.environ.copy()
env["PYTHONUNBUFFERED"] = "1"
print(f"🚀 Bắt đầu train XD-Violence bản FINAL (no Otsu + WarmStart) với {MAX_EPOCHS} Epochs...\n", flush=True)
with log_path.open("w", encoding="utf-8") as log_file:
    process = subprocess.Popen(
        cmd, cwd=REPO, env=env, text=True,
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=1,
    )
    
    # Ép đọc và in theo từng ký tự (character) để phá vỡ bộ đệm của tqdm
    while True:
        char = process.stdout.read(1)
        if not char:
            break
        print(char, end="")
        sys.stdout.flush()
        log_file.write(char)
        log_file.flush()
        
    return_code = process.wait()
if return_code != 0:
    raise RuntimeError(f"❌ Training thất bại với exit code {return_code}")
print(f"\n✅ Hoàn thành xuất sắc trong {(time.time() - started)/3600:.2f} giờ!")
# Out:
# 🚀 Bắt đầu train XD-Violence bản FINAL (no Otsu + WarmStart) với 10 Epochs...
#
# /kaggle/working/RUPA-DSA/src/clip/clip.py:57: UserWarning: /root/.cache/clip/ViT-B-16.pt exists, but the SHA256 checksum does not match; re-downloading the file
#   warnings.warn(f"{download_target} exists, but the SHA256 checksum does not match; re-downloading the file")
#
#   0%|                                               | 0.00/335M [00:00<?, ?iB/s]
#   0%|                                       | 416k/335M [00:00<01:22, 4.25MiB/s]
#   1%|▎                                     | 2.36M/335M [00:00<00:28, 12.3MiB/s]
#   2%|▉                                     | 7.94M/335M [00:00<00:10, 32.0MiB/s]
#   3%|█▎                                    | 11.1M/335M [00:00<00:13, 24.5MiB/s]
#   5%|██                                    | 18.2M/335M [00:00<00:08, 39.2MiB/s]
#   7%|██▋                                   | 24.1M/335M [00:00<00:07, 44.4MiB/s]
#   9%|███▎                                  | 28.7M/335M [00:01<00:30, 10.7MiB/s]
#  10%|███▋                                  | 32.5M/335M [00:02<00:23, 13.3MiB/s]
#  12%|████▍                                 | 38.6M/335M [00:02<00:16, 18.9MiB/s]
#  13%|████▊                                 | 42.9M/335M [00:02<00:13, 22.1MiB/s]
#  14%|█████▌                                | 48.4M/335M [00:02<00:10, 28.0MiB/s]
#  16%|██████                                | 53.8M/335M [00:02<00:09, 32.2MiB/s]
#  17%|██████▋                               | 58.4M/335M [00:02<00:10, 27.2MiB/s]
#  19%|███████▎                              | 64.2M/335M [00:02<00:08, 33.4MiB/s]
#  20%|███████▊                              | 68.6M/335M [00:02<00:08, 34.7MiB/s]
#  22%|████████▎                             | 73.7M/335M [00:03<00:06, 39.1MiB/s]
#  24%|█████████▏                            | 80.4M/335M [00:03<00:05, 46.4MiB/s]
#  26%|█████████▉                            | 87.7M/335M [00:03<00:04, 54.2MiB/s]
#  28%|██████████▌                           | 93.5M/335M [00:03<00:07, 31.9MiB/s]
#  29%|███████████▏                          | 98.0M/335M [00:03<00:07, 32.9MiB/s]
#  31%|████████████▏                          | 104M/335M [00:03<00:06, 39.4MiB/s]
#  33%|████████████▋                          | 109M/335M [00:03<00:05, 40.2MiB/s]
#  34%|█████████████▎                         | 114M/335M [00:04<00:05, 39.3MiB/s]
#  36%|█████████████▉                         | 120M/335M [00:04<00:04, 45.5MiB/s]
#  37%|██████████████▌                        | 125M/335M [00:04<00:05, 39.8MiB/s]
#  39%|███████████████                        | 129M/335M [00:04<00:05, 37.3MiB/s]
#  40%|███████████████▌                       | 133M/335M [00:04<00:05, 37.0MiB/s]
#  41%|███████████████▉                       | 137M/335M [00:04<00:06, 30.8MiB/s]
#  43%|████████████████▊                      | 144M/335M [00:04<00:05, 40.0MiB/s]
#  44%|█████████████████▎                     | 148M/335M [00:05<00:08, 22.5MiB/s]
#  46%|█████████████████▊                     | 152M/335M [00:05<00:07, 26.2MiB/s]
#  47%|██████████████████▌                    | 159M/335M [00:05<00:05, 33.3MiB/s]
#  49%|███████████████████                    | 163M/335M [00:05<00:05, 34.7MiB/s]
#  50%|███████████████████▌                   | 167M/335M [00:05<00:04, 37.0MiB/s]
#  51%|████████████████████                   | 172M/335M [00:05<00:05, 32.6MiB/s]
#  53%|████████████████████▌                  | 177M/335M [00:06<00:04, 36.7MiB/s]
#  55%|█████████████████████▎                 | 182M/335M [00:06<00:03, 42.8MiB/s]
#  56%|█████████████████████▊                 | 187M/335M [00:06<00:03, 42.3MiB/s]
#  57%|██████████████████████▍                | 192M/335M [00:06<00:03, 43.6MiB/s]
#  59%|██████████████████████▉                | 196M/335M [00:06<00:03, 41.1MiB/s]
#  60%|███████████████████████▍               | 201M/335M [00:06<00:03, 41.3MiB/s]
#  62%|████████████████████████▏              | 208M/335M [00:06<00:02, 48.8MiB/s]
#  64%|█████████████████████████              | 215M/335M [00:06<00:02, 55.9MiB/s]
#  66%|█████████████████████████▋             | 221M/335M [00:06<00:02, 49.2MiB/s]
#  67%|██████████████████████████▎            | 226M/335M [00:07<00:02, 49.7MiB/s]
#  69%|██████████████████████████▊            | 230M/335M [00:07<00:02, 45.7MiB/s]
#  70%|███████████████████████████▍           | 235M/335M [00:08<00:06, 15.9MiB/s]
#  72%|███████████████████████████▉           | 240M/335M [00:08<00:04, 19.9MiB/s]
#  73%|████████████████████████████▌          | 245M/335M [00:08<00:03, 25.0MiB/s]
#  75%|█████████████████████████████          | 250M/335M [00:08<00:03, 27.4MiB/s]
#  77%|█████████████████████████████▊         | 256M/335M [00:08<00:02, 34.6MiB/s]
#  78%|██████████████████████████████▍        | 261M/335M [00:08<00:02, 36.6MiB/s]
#  79%|██████████████████████████████▉        | 265M/335M [00:08<00:02, 33.4MiB/s]
#  81%|███████████████████████████████▋       | 272M/335M [00:08<00:01, 40.5MiB/s]
#  83%|████████████████████████████████▏      | 277M/335M [00:09<00:01, 37.4MiB/s]
#  84%|████████████████████████████████▊      | 282M/335M [00:09<00:01, 40.8MiB/s]
#  86%|█████████████████████████████████▌     | 288M/335M [00:09<00:01, 42.2MiB/s]
#  87%|██████████████████████████████████     | 292M/335M [00:09<00:01, 37.0MiB/s]
#  89%|██████████████████████████████████▌    | 296M/335M [00:09<00:01, 37.9MiB/s]
#  90%|██████████████████████████████████▉    | 300M/335M [00:09<00:01, 34.4MiB/s]
#  91%|███████████████████████████████████▌   | 306M/335M [00:09<00:00, 39.7MiB/s]
#  93%|████████████████████████████████████▎  | 311M/335M [00:09<00:00, 45.2MiB/s]
#  95%|████████████████████████████████████▉  | 316M/335M [00:10<00:00, 47.0MiB/s]
#  96%|█████████████████████████████████████▍ | 321M/335M [00:10<00:00, 39.2MiB/s]
#  98%|██████████████████████████████████████▎| 328M/335M [00:10<00:00, 48.0MiB/s]
# 100%|██████████████████████████████████████▉| 334M/335M [00:10<00:00, 49.9MiB/s]
# 100%|███████████████████████████████████████| 335M/335M [00:10<00:00, 33.5MiB/s]
# Loading initial model weights from /kaggle/input/models/vhunhquang/dsanet-checkpoint/pytorch/default/1/dsanet_model_xd.pth
# epoch: 1 | step: 4800 | loss1: 0.1946 | loss2: 0.5212 | loss3: 0.0427 | loss4: 1.1256 | loss5: 0.6855 | consistency_loss: 0.0083 | g_loss: 0.2224 | dnp_normal_loss: 0.9654
# epoch: 1 | step: 9600 | loss1: 0.2064 | loss2: 0.5315 | loss3: 0.0427 | loss4: 1.1338 | loss5: 0.6661 | consistency_loss: 0.0069 | g_loss: 0.1951 | dnp_normal_loss: 0.9523
# epoch: 1 | step: 14400 | loss1: 0.2115 | loss2: 0.5394 | loss3: 0.0427 | loss4: 1.1399 | loss5: 0.6599 | consistency_loss: 0.0085 | g_loss: 0.1909 | dnp_normal_loss: 0.9363
# epoch: 1 | step: 19200 | loss1: 0.2110 | loss2: 0.5444 | loss3: 0.0427 | loss4: 1.1397 | loss5: 0.6571 | consistency_loss: 0.0127 | g_loss: 0.1751 | dnp_normal_loss: 0.9129
# epoch: 1 | step: 24000 | loss1: 0.2106 | loss2: 0.5466 | loss3: 0.0427 | loss4: 1.1335 | loss5: 0.6560 | consistency_loss: 0.0147 | g_loss: 0.1546 | dnp_normal_loss: 0.8923
# epoch: 1 | step: 28800 | loss1: 0.2111 | loss2: 0.5475 | loss3: 0.0427 | loss4: 1.1232 | loss5: 0.6555 | consistency_loss: 0.0204 | g_loss: 0.1453 | dnp_normal_loss: 0.8780
# epoch: 1 | step: 33600 | loss1: 0.2103 | loss2: 0.5476 | loss3: 0.0427 | loss4: 1.1136 | loss5: 0.6554 | consistency_loss: 0.0204 | g_loss: 0.1400 | dnp_normal_loss: 0.8539
# epoch: 1 | step: 38400 | loss1: 0.2103 | loss2: 0.5487 | loss3: 0.0427 | loss4: 1.1046 | loss5: 0.6556 | consistency_loss: 0.0273 | g_loss: 0.1307 | dnp_normal_loss: 0.8415
# AUC1:  0.9539597224628794  AP1:  0.8694411940393748
# AUC2:  0.9539597223301881  AP2: 0.869441193175557
# mAP@0.1 =38.83%
# mAP@0.2 =32.55%
# mAP@0.3 =26.69%
# mAP@0.4 =20.17%
# mAP@0.5 =15.43%
# average MAP: 26.73
# epoch: 2 | step: 4800 | loss1: 0.2073 | loss2: 0.5580 | loss3: 0.0427 | loss4: 1.0209 | loss5: 0.6554 | consistency_loss: 0.0206 | g_loss: 0.1184 | dnp_normal_loss: 0.8116
# epoch: 2 | step: 9600 | loss1: 0.2117 | loss2: 0.5555 | loss3: 0.0427 | loss4: 1.0104 | loss5: 0.6555 | consistency_loss: 0.0201 | g_loss: 0.1204 | dnp_normal_loss: 0.7946
# epoch: 2 | step: 14400 | loss1: 0.2104 | loss2: 0.5526 | loss3: 0.0427 | loss4: 1.0019 | loss5: 0.6555 | consistency_loss: 0.0245 | g_loss: 0.1144 | dnp_normal_loss: 0.7764
# epoch: 2 | step: 19200 | loss1: 0.2068 | loss2: 0.5488 | loss3: 0.0427 | loss4: 0.9920 | loss5: 0.6554 | consistency_loss: 0.0265 | g_loss: 0.1121 | dnp_normal_loss: 0.7593
# epoch: 2 | step: 24000 | loss1: 0.2071 | loss2: 0.5481 | loss3: 0.0427 | loss4: 0.9851 | loss5: 0.6551 | consistency_loss: 0.0187 | g_loss: 0.1052 | dnp_normal_loss: 0.7356
# epoch: 2 | step: 28800 | loss1: 0.2075 | loss2: 0.5477 | loss3: 0.0427 | loss4: 0.9793 | loss5: 0.6554 | consistency_loss: 0.0239 | g_loss: 0.1136 | dnp_normal_loss: 0.7245
# epoch: 2 | step: 33600 | loss1: 0.2094 | loss2: 0.5504 | loss3: 0.0427 | loss4: 0.9743 | loss5: 0.6551 | consistency_loss: 0.0188 | g_loss: 0.1121 | dnp_normal_loss: 0.7051
# epoch: 2 | step: 38400 | loss1: 0.2096 | loss2: 0.5468 | loss3: 0.0427 | loss4: 0.9664 | loss5: 0.6550 | consistency_loss: 0.0213 | g_loss: 0.1026 | dnp_normal_loss: 0.6891
# AUC1:  0.9539688736998639  AP1:  0.8696761171550497
# AUC2:  0.9539688729120096  AP2: 0.8696761157385511
# mAP@0.1 =38.83%
# mAP@0.2 =32.70%
# mAP@0.3 =26.88%
# mAP@0.4 =20.72%
# mAP@0.5 =16.18%
# average MAP: 27.06
# epoch: 3 | step: 4800 | loss1: 0.2095 | loss2: 0.5669 | loss3: 0.0427 | loss4: 0.9490 | loss5: 0.6535 | consistency_loss: 0.0219 | g_loss: 0.1001 | dnp_normal_loss: 0.6604
# epoch: 3 | step: 9600 | loss1: 0.2121 | loss2: 0.5592 | loss3: 0.0427 | loss4: 0.9322 | loss5: 0.6540 | consistency_loss: 0.0209 | g_loss: 0.1046 | dnp_normal_loss: 0.6353
# epoch: 3 | step: 14400 | loss1: 0.2111 | loss2: 0.5509 | loss3: 0.0427 | loss4: 0.9204 | loss5: 0.6539 | consistency_loss: 0.0238 | g_loss: 0.1028 | dnp_normal_loss: 0.6226
# epoch: 3 | step: 19200 | loss1: 0.2119 | loss2: 0.5531 | loss3: 0.0427 | loss4: 0.9192 | loss5: 0.6538 | consistency_loss: 0.0187 | g_loss: 0.1028 | dnp_normal_loss: 0.6120
# epoch: 3 | step: 24000 | loss1: 0.2101 | loss2: 0.5510 | loss3: 0.0427 | loss4: 0.9163 | loss5: 0.6537 | consistency_loss: 0.0228 | g_loss: 0.1025 | dnp_normal_loss: 0.5921
# epoch: 3 | step: 28800 | loss1: 0.2092 | loss2: 0.5488 | loss3: 0.0427 | loss4: 0.9111 | loss5: 0.6538 | consistency_loss: 0.0216 | g_loss: 0.1011 | dnp_normal_loss: 0.5712
# epoch: 3 | step: 33600 | loss1: 0.2097 | loss2: 0.5476 | loss3: 0.0427 | loss4: 0.9078 | loss5: 0.6536 | consistency_loss: 0.0256 | g_loss: 0.1085 | dnp_normal_loss: 0.5546
# epoch: 3 | step: 38400 | loss1: 0.2103 | loss2: 0.5480 | loss3: 0.0427 | loss4: 0.9061 | loss5: 0.6536 | consistency_loss: 0.0186 | g_loss: 0.1056 | dnp_normal_loss: 0.5348
# AUC1:  0.9539788968429956  AP1:  0.8697262792914471
# AUC2:  0.9539788963785761  AP2: 0.8697262787868841
# mAP@0.1 =38.65%
# mAP@0.2 =32.68%
# mAP@0.3 =26.56%
# mAP@0.4 =21.06%
# mAP@0.5 =16.29%
# average MAP: 27.05
# epoch: 4 | step: 4800 | loss1: 0.2201 | loss2: 0.5645 | loss3: 0.0427 | loss4: 0.8846 | loss5: 0.6526 | consistency_loss: 0.0198 | g_loss: 0.0992 | dnp_normal_loss: 0.5229
# epoch: 4 | step: 9600 | loss1: 0.2168 | loss2: 0.5443 | loss3: 0.0427 | loss4: 0.8733 | loss5: 0.6534 | consistency_loss: 0.0201 | g_loss: 0.0978 | dnp_normal_loss: 0.5064
# epoch: 4 | step: 14400 | loss1: 0.2135 | loss2: 0.5380 | loss3: 0.0427 | loss4: 0.8720 | loss5: 0.6536 | consistency_loss: 0.0233 | g_loss: 0.1012 | dnp_normal_loss: 0.4943
# epoch: 4 | step: 19200 | loss1: 0.2109 | loss2: 0.5429 | loss3: 0.0427 | loss4: 0.8729 | loss5: 0.6536 | consistency_loss: 0.0246 | g_loss: 0.1027 | dnp_normal_loss: 0.4851
# epoch: 4 | step: 24000 | loss1: 0.2102 | loss2: 0.5478 | loss3: 0.0427 | loss4: 0.8702 | loss5: 0.6536 | consistency_loss: 0.0250 | g_loss: 0.0959 | dnp_normal_loss: 0.4669
# epoch: 4 | step: 28800 | loss1: 0.2101 | loss2: 0.5464 | loss3: 0.0427 | loss4: 0.8665 | loss5: 0.6537 | consistency_loss: 0.0158 | g_loss: 0.0969 | dnp_normal_loss: 0.4600
# epoch: 4 | step: 33600 | loss1: 0.2112 | loss2: 0.5498 | loss3: 0.0427 | loss4: 0.8676 | loss5: 0.6537 | consistency_loss: 0.0140 | g_loss: 0.0946 | dnp_normal_loss: 0.4509
# epoch: 4 | step: 38400 | loss1: 0.2099 | loss2: 0.5476 | loss3: 0.0427 | loss4: 0.8645 | loss5: 0.6536 | consistency_loss: 0.0180 | g_loss: 0.1006 | dnp_normal_loss: 0.4506
# AUC1:  0.9539960840715864  AP1:  0.8697871396847345
# AUC2:  0.953996083938895  AP2: 0.8697871391167574
# mAP@0.1 =39.22%
# mAP@0.2 =33.48%
# mAP@0.3 =27.62%
# mAP@0.4 =22.30%
# mAP@0.5 =16.60%
# average MAP: 27.84
# epoch: 5 | step: 4800 | loss1: 0.2051 | loss2: 0.5296 | loss3: 0.0427 | loss4: 0.8291 | loss5: 0.6550 | consistency_loss: 0.0155 | g_loss: 0.0944 | dnp_normal_loss: 0.4319
# epoch: 5 | step: 9600 | loss1: 0.2089 | loss2: 0.5437 | loss3: 0.0427 | loss4: 0.8257 | loss5: 0.6539 | consistency_loss: 0.0189 | g_loss: 0.1002 | dnp_normal_loss: 0.4242
# epoch: 5 | step: 14400 | loss1: 0.2107 | loss2: 0.5465 | loss3: 0.0427 | loss4: 0.8291 | loss5: 0.6539 | consistency_loss: 0.0178 | g_loss: 0.0941 | dnp_normal_loss: 0.4267
# epoch: 5 | step: 19200 | loss1: 0.2073 | loss2: 0.5428 | loss3: 0.0427 | loss4: 0.8341 | loss5: 0.6534 | consistency_loss: 0.0255 | g_loss: 0.1040 | dnp_normal_loss: 0.4216
# epoch: 5 | step: 24000 | loss1: 0.2090 | loss2: 0.5437 | loss3: 0.0427 | loss4: 0.8338 | loss5: 0.6532 | consistency_loss: 0.0197 | g_loss: 0.0978 | dnp_normal_loss: 0.4120
# epoch: 5 | step: 28800 | loss1: 0.2082 | loss2: 0.5453 | loss3: 0.0427 | loss4: 0.8344 | loss5: 0.6532 | consistency_loss: 0.0219 | g_loss: 0.0946 | dnp_normal_loss: 0.4061
# epoch: 5 | step: 33600 | loss1: 0.2091 | loss2: 0.5478 | loss3: 0.0427 | loss4: 0.8309 | loss5: 0.6532 | consistency_loss: 0.0140 | g_loss: 0.0928 | dnp_normal_loss: 0.3959
# epoch: 5 | step: 38400 | loss1: 0.2100 | loss2: 0.5486 | loss3: 0.0427 | loss4: 0.8292 | loss5: 0.6532 | consistency_loss: 0.0160 | g_loss: 0.0923 | dnp_normal_loss: 0.4000
# AUC1:  0.9540333078253372  AP1:  0.8702383683804502
# AUC2:  0.954033307974615  AP2: 0.870238367970186
# mAP@0.1 =39.93%
# mAP@0.2 =33.93%
# mAP@0.3 =27.74%
# mAP@0.4 =22.07%
# mAP@0.5 =16.99%
# average MAP: 28.13
# epoch: 6 | step: 4800 | loss1: 0.2239 | loss2: 0.5579 | loss3: 0.0427 | loss4: 0.8014 | loss5: 0.6533 | consistency_loss: 0.0186 | g_loss: 0.0925 | dnp_normal_loss: 0.3931
# epoch: 6 | step: 9600 | loss1: 0.2176 | loss2: 0.5573 | loss3: 0.0427 | loss4: 0.8072 | loss5: 0.6527 | consistency_loss: 0.0133 | g_loss: 0.0915 | dnp_normal_loss: 0.3824
# epoch: 6 | step: 14400 | loss1: 0.2136 | loss2: 0.5538 | loss3: 0.0427 | loss4: 0.8062 | loss5: 0.6531 | consistency_loss: 0.0232 | g_loss: 0.0931 | dnp_normal_loss: 0.3863
# epoch: 6 | step: 19200 | loss1: 0.2130 | loss2: 0.5501 | loss3: 0.0427 | loss4: 0.8065 | loss5: 0.6528 | consistency_loss: 0.0167 | g_loss: 0.0908 | dnp_normal_loss: 0.3794
# epoch: 6 | step: 24000 | loss1: 0.2136 | loss2: 0.5512 | loss3: 0.0427 | loss4: 0.8038 | loss5: 0.6526 | consistency_loss: 0.0148 | g_loss: 0.0945 | dnp_normal_loss: 0.3741
# epoch: 6 | step: 28800 | loss1: 0.2113 | loss2: 0.5485 | loss3: 0.0427 | loss4: 0.7983 | loss5: 0.6527 | consistency_loss: 0.0176 | g_loss: 0.0921 | dnp_normal_loss: 0.3689
# epoch: 6 | step: 33600 | loss1: 0.2108 | loss2: 0.5479 | loss3: 0.0427 | loss4: 0.7959 | loss5: 0.6526 | consistency_loss: 0.0203 | g_loss: 0.0977 | dnp_normal_loss: 0.3720
# epoch: 6 | step: 38400 | loss1: 0.2092 | loss2: 0.5468 | loss3: 0.0427 | loss4: 0.7937 | loss5: 0.6527 | consistency_loss: 0.0170 | g_loss: 0.0968 | dnp_normal_loss: 0.3624
# AUC1:  0.9540120416997898  AP1:  0.870074130296608
# AUC2:  0.9540120415670985  AP2: 0.8700741293615949
# mAP@0.1 =39.10%
# mAP@0.2 =33.42%
# mAP@0.3 =27.77%
# mAP@0.4 =22.03%
# mAP@0.5 =15.81%
# average MAP: 27.63
# epoch: 7 | step: 4800 | loss1: 0.2147 | loss2: 0.5664 | loss3: 0.0427 | loss4: 0.7774 | loss5: 0.6525 | consistency_loss: 0.0177 | g_loss: 0.0901 | dnp_normal_loss: 0.3599
# epoch: 7 | step: 9600 | loss1: 0.2183 | loss2: 0.5562 | loss3: 0.0427 | loss4: 0.7679 | loss5: 0.6523 | consistency_loss: 0.0174 | g_loss: 0.0918 | dnp_normal_loss: 0.3513
# epoch: 7 | step: 14400 | loss1: 0.2151 | loss2: 0.5521 | loss3: 0.0427 | loss4: 0.7582 | loss5: 0.6520 | consistency_loss: 0.0143 | g_loss: 0.0914 | dnp_normal_loss: 0.3541
# epoch: 7 | step: 19200 | loss1: 0.2131 | loss2: 0.5515 | loss3: 0.0427 | loss4: 0.7614 | loss5: 0.6519 | consistency_loss: 0.0225 | g_loss: 0.0934 | dnp_normal_loss: 0.3559
# epoch: 7 | step: 24000 | loss1: 0.2131 | loss2: 0.5505 | loss3: 0.0427 | loss4: 0.7620 | loss5: 0.6523 | consistency_loss: 0.0138 | g_loss: 0.0917 | dnp_normal_loss: 0.3473
# epoch: 7 | step: 28800 | loss1: 0.2119 | loss2: 0.5489 | loss3: 0.0427 | loss4: 0.7616 | loss5: 0.6522 | consistency_loss: 0.0186 | g_loss: 0.0925 | dnp_normal_loss: 0.3514
# epoch: 7 | step: 33600 | loss1: 0.2098 | loss2: 0.5468 | loss3: 0.0427 | loss4: 0.7588 | loss5: 0.6522 | consistency_loss: 0.0176 | g_loss: 0.0991 | dnp_normal_loss: 0.3497
# epoch: 7 | step: 38400 | loss1: 0.2099 | loss2: 0.5485 | loss3: 0.0427 | loss4: 0.7578 | loss5: 0.6522 | consistency_loss: 0.0140 | g_loss: 0.0966 | dnp_normal_loss: 0.3409
# AUC1:  0.9540395728775752  AP1:  0.8702212962737605
# AUC2:  0.9540395729356278  AP2: 0.8702212957370472
# mAP@0.1 =39.37%
# mAP@0.2 =33.72%
# mAP@0.3 =27.35%
# mAP@0.4 =21.80%
# mAP@0.5 =16.17%
# average MAP: 27.68
# epoch: 8 | step: 4800 | loss1: 0.2094 | loss2: 0.5494 | loss3: 0.0427 | loss4: 0.7354 | loss5: 0.6517 | consistency_loss: 0.0170 | g_loss: 0.0896 | dnp_normal_loss: 0.3428
# epoch: 8 | step: 9600 | loss1: 0.2075 | loss2: 0.5442 | loss3: 0.0427 | loss4: 0.7311 | loss5: 0.6524 | consistency_loss: 0.0148 | g_loss: 0.0909 | dnp_normal_loss: 0.3356
# epoch: 8 | step: 14400 | loss1: 0.2090 | loss2: 0.5576 | loss3: 0.0427 | loss4: 0.7341 | loss5: 0.6524 | consistency_loss: 0.0164 | g_loss: 0.0886 | dnp_normal_loss: 0.3374
# epoch: 8 | step: 19200 | loss1: 0.2089 | loss2: 0.5527 | loss3: 0.0427 | loss4: 0.7328 | loss5: 0.6521 | consistency_loss: 0.0174 | g_loss: 0.0880 | dnp_normal_loss: 0.3336
# epoch: 8 | step: 24000 | loss1: 0.2095 | loss2: 0.5491 | loss3: 0.0427 | loss4: 0.7343 | loss5: 0.6521 | consistency_loss: 0.0143 | g_loss: 0.0836 | dnp_normal_loss: 0.3346
# epoch: 8 | step: 28800 | loss1: 0.2109 | loss2: 0.5477 | loss3: 0.0427 | loss4: 0.7325 | loss5: 0.6520 | consistency_loss: 0.0184 | g_loss: 0.0921 | dnp_normal_loss: 0.3329
# epoch: 8 | step: 33600 | loss1: 0.2110 | loss2: 0.5489 | loss3: 0.0427 | loss4: 0.7318 | loss5: 0.6520 | consistency_loss: 0.0167 | g_loss: 0.0943 | dnp_normal_loss: 0.3330
# epoch: 8 | step: 38400 | loss1: 0.2098 | loss2: 0.5470 | loss3: 0.0427 | loss4: 0.7276 | loss5: 0.6521 | consistency_loss: 0.0152 | g_loss: 0.0852 | dnp_normal_loss: 0.3327
# AUC1:  0.9540418498102826  AP1:  0.8702232165685283
# AUC2:  0.954041849942974  AP2: 0.8702232161428699
# mAP@0.1 =40.03%
# mAP@0.2 =34.43%
# mAP@0.3 =28.81%
# mAP@0.4 =21.93%
# mAP@0.5 =16.59%
# average MAP: 28.36
# epoch: 9 | step: 4800 | loss1: 0.2013 | loss2: 0.5385 | loss3: 0.0427 | loss4: 0.7145 | loss5: 0.6523 | consistency_loss: 0.0188 | g_loss: 0.0873 | dnp_normal_loss: 0.3302
# epoch: 9 | step: 9600 | loss1: 0.2029 | loss2: 0.5423 | loss3: 0.0427 | loss4: 0.7124 | loss5: 0.6520 | consistency_loss: 0.0188 | g_loss: 0.0884 | dnp_normal_loss: 0.3304
# epoch: 9 | step: 14400 | loss1: 0.2048 | loss2: 0.5434 | loss3: 0.0427 | loss4: 0.7081 | loss5: 0.6520 | consistency_loss: 0.0184 | g_loss: 0.0981 | dnp_normal_loss: 0.3296
# epoch: 9 | step: 19200 | loss1: 0.2069 | loss2: 0.5446 | loss3: 0.0427 | loss4: 0.7054 | loss5: 0.6520 | consistency_loss: 0.0189 | g_loss: 0.0965 | dnp_normal_loss: 0.3278
# epoch: 9 | step: 24000 | loss1: 0.2073 | loss2: 0.5470 | loss3: 0.0427 | loss4: 0.7059 | loss5: 0.6520 | consistency_loss: 0.0172 | g_loss: 0.0823 | dnp_normal_loss: 0.3243
# epoch: 9 | step: 28800 | loss1: 0.2091 | loss2: 0.5485 | loss3: 0.0427 | loss4: 0.7031 | loss5: 0.6521 | consistency_loss: 0.0214 | g_loss: 0.0930 | dnp_normal_loss: 0.3252
# epoch: 9 | step: 33600 | loss1: 0.2087 | loss2: 0.5486 | loss3: 0.0427 | loss4: 0.7012 | loss5: 0.6521 | consistency_loss: 0.0135 | g_loss: 0.0844 | dnp_normal_loss: 0.3205
# epoch: 9 | step: 38400 | loss1: 0.2095 | loss2: 0.5473 | loss3: 0.0427 | loss4: 0.6982 | loss5: 0.6521 | consistency_loss: 0.0165 | g_loss: 0.0842 | dnp_normal_loss: 0.3199
# AUC1:  0.9540371360435753  AP1:  0.870224440345759
# AUC2:  0.9540371367070317  AP2: 0.8702244398917601
# mAP@0.1 =38.87%
# mAP@0.2 =33.79%
# mAP@0.3 =27.56%
# mAP@0.4 =21.59%
# mAP@0.5 =16.40%
# average MAP: 27.64
# epoch: 10 | step: 4800 | loss1: 0.2159 | loss2: 0.5644 | loss3: 0.0427 | loss4: 0.6934 | loss5: 0.6528 | consistency_loss: 0.0164 | g_loss: 0.0879 | dnp_normal_loss: 0.3218
# epoch: 10 | step: 9600 | loss1: 0.2155 | loss2: 0.5632 | loss3: 0.0427 | loss4: 0.6920 | loss5: 0.6523 | consistency_loss: 0.0178 | g_loss: 0.0870 | dnp_normal_loss: 0.3230
# epoch: 10 | step: 14400 | loss1: 0.2160 | loss2: 0.5575 | loss3: 0.0427 | loss4: 0.6879 | loss5: 0.6520 | consistency_loss: 0.0185 | g_loss: 0.0934 | dnp_normal_loss: 0.3202
# epoch: 10 | step: 19200 | loss1: 0.2141 | loss2: 0.5580 | loss3: 0.0427 | loss4: 0.6872 | loss5: 0.6520 | consistency_loss: 0.0169 | g_loss: 0.0921 | dnp_normal_loss: 0.3239
# epoch: 10 | step: 24000 | loss1: 0.2118 | loss2: 0.5508 | loss3: 0.0427 | loss4: 0.6843 | loss5: 0.6519 | consistency_loss: 0.0187 | g_loss: 0.0894 | dnp_normal_loss: 0.3228
# epoch: 10 | step: 28800 | loss1: 0.2107 | loss2: 0.5474 | loss3: 0.0427 | loss4: 0.6845 | loss5: 0.6519 | consistency_loss: 0.0179 | g_loss: 0.0888 | dnp_normal_loss: 0.3181
# epoch: 10 | step: 33600 | loss1: 0.2102 | loss2: 0.5489 | loss3: 0.0427 | loss4: 0.6853 | loss5: 0.6519 | consistency_loss: 0.0159 | g_loss: 0.0916 | dnp_normal_loss: 0.3192
# epoch: 10 | step: 38400 | loss1: 0.2099 | loss2: 0.5482 | loss3: 0.0427 | loss4: 0.6828 | loss5: 0.6520 | consistency_loss: 0.0157 | g_loss: 0.0851 | dnp_normal_loss: 0.3170
# AUC1:  0.9540387081616379  AP1:  0.8701849140233257
# AUC2:  0.9540387076723387  AP2: 0.8701849128996448
# mAP@0.1 =39.04%
# mAP@0.2 =33.75%
# mAP@0.3 =27.79%
# mAP@0.4 =21.55%
# mAP@0.5 =15.78%
# average MAP: 27.58
#
# ✅ Hoàn thành xuất sắc trong 1.69 giờ!
